# %%
from src.logger import logger
logger.info("Installation test successful!")
# Out:
# {"timestamp": "2026-01-04 22:55:10,003", "level": "INFO", "message": "Installation test successful!", "file": "setup_test.ipynb", "line": 2}
